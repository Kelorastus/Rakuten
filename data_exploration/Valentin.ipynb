# %% [markdown]
# # Exploration
# ## Variables d'entrée

# %%
import pandas as pd

# %%
X = pd.read_csv('../Dataset/X_train.csv',index_col=0)
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84916 entries, 0 to 84915
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   designation  84916 non-null  object
#  1   description  55116 non-null  object
#  2   productid    84916 non-null  int64
#  3   imageid      84916 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 3.2+ MB

# %%
if not X.index.is_unique:
    print("Warning: Duplicate indices found!")

# %%
X.head(30)
# Out:
#                                           designation  \
# 0   Olivia: Personalisiertes Notizbuch / 150 Seite...
# 1   Journal Des Arts (Le) N° 133 Du 28/09/2001 - L...
# 2   Grand Stylet Ergonomique Bleu Gamepad Nintendo...
# 3   Peluche Donald - Europe - Disneyland 2000 (Mar...
# 4                                La Guerre Des Tuques
# 5   Afrique Contemporaine N° 212 Hiver 2004 - Doss...
# 6          Christof E: Bildungsprozessen Auf Der Spur
# 7   Conquérant Sept Cahier Couverture Polypro 240 ...
# 8           Puzzle Scooby-Doo Avec Poster 2x35 Pieces
# 9   Tente Pliante V3s5-Pro Pvc Blanc - 3 X 4m50 - ...
# 10            Eames Inspired Sxw Chair - Pink - Black
# 11  Fauteuil Chesterfield Brenton 100% Cuir De Buf...
# 12  Peaceable Kingdom Wheres Bear? The Hide And Fi...
# 13               Paire De Voilages Imprimés Fantaisie
# 14  Matelas Mémoire De Forme 180x200 X 20 Cm Très ...
# 15       Zenith Pince Agrafeuse 591 N°10 Coloris Noir
# 16  Walter Scott Oeuvres Complètes Tomes 3456 10 E...
# 17                Mod Podge Dishwasher Safe Gloss 8oz
# 18  Power Rangers Rouge Force Mystic Figurine Tran...
# 19  Monde Illustre (Le) N° 3083 Du 20/01/1917 - L'...
# 20    Kit de désinfection pour piscines enfants 20990
# 21                     Glitter Beach Barbie By Barbie
# 22  Le Seigneur Des Anneaux Figurine En Plomb À Pe...
# 23                          Véhicule Star Wars A-Ast5
# 24  Mini Wifi 720p Caméra Drone Rc Quadcopter 24 G...
# 25                 Dsi + Chargeur + Sacoche + 12 Jeux
# 26  Modèle De Voiture 4pcs Alliage Métallique 1.9i...
# 27  Faber-Castell Lot De 3 Crayons De Couleur Poly...
# 28  Univers (L') N° 249 Du 12/09/1854 - France - P...
# 29  Dragon Ball Super - Bt3-070 - C-13 Les Prémiss...
#
#                                           description   productid     imageid
# 0                                                 NaN  3804725264  1263597046
# 1                                                 NaN   436067568  1008141237
# 2   PILOT STYLE Touch Pen de marque Speedlink est ...   201115110   938777978
# 3                                                 NaN    50418756   457047496
# 4   Luc a des id&eacute;es de grandeur. Il veut or...   278535884  1077757786
# 5                                                 NaN     5862738   393356830
# 6                                                 NaN    91920807   907794536
# 7   CONQUERANT CLASSIQUE Cahier 240 x 320 mm seyès...   344240059   999581347
# 8                                                 NaN  4239126071  1325918866
# 9   Tente pliante V3S5 Pro PVC 500 gr/m² - 3 x 4m5...  3793572222  1245644185
# 10  The timeless DSW seat can now be paired with m...  1915836983  1111840281
# 11  Canapé et fauteuil chesterfield en cuir antiqu...  4127967621  1295816984
# 12  pCan my 2-year-old play a game? Yes Each game ...  3287127001  1204199842
# 13  Paire de voilages droits fantaisie qui mettra ...  1882164320  1109088140
# 14  MATELAS:<br />Â· Accueil : Ferme .<br />Â· Sou...  4108914287  1292441752
# 15  Pince agrafeuse 591 N°10. Capot en ABS. Dispos...  3718150116  1237257586
# 16                                                NaN  3735707499  1239242410
# 17                                                NaN  2666371748  1156191369
# 18                                                NaN    91015572   857195931
# 19                                                NaN   570628142  1027257229
# 20                                                NaN  3936362802  1268740880
# 21    Original Barbie Doll. Contains glitter lotion..  3228900895  1199384348
# 22                                                NaN  1893048509  1110089245
# 23    véhicule vintage de la saga star wars le A-AST5   279822475   978593209
# 24  Mini Wifi 720P Caméra Drone RC Quadcopter 24 G...  3748203527  1240721678
# 25                                                NaN   211334790   948608572
# 26  4pcs alliage métallique 1.9in jante de roue po...  4137059841  1297749086
# 27  FABER-CASTELL Crayon de couleur POLYCHROMOS ve...  2536863974  1148154575
# 28                                                NaN   570663184  1027317460
# 29                                                NaN  3226779852  1202890774

# %% [markdown]
# Les variables imageid et productid semblent inutiles pour la prédiction, et servir juste à associer l'image correspondante lors du preprocessing. Il y a donc essentiellement 3 variables a priori : designation, description, image. Ce petit nombre de variables est une difficulté. En revanche, ces variables semblent avoir un contenu riche et complexe, ce qui offre un potentiel fort si on parvient à les exploiter.

# %%
# L'ID est sans doublon, pas de problème.
X.productid.nunique()
# Out:
# 84916

# %%
# L'ID est sans doublon, pas de problème.
X.imageid.nunique()
# Out:
# 84916

# %% [markdown]
# ### Variables textuelles

# %% [markdown]
# Les textes sont en au moins 3 langues (allemand, français, anglais), ce qui peut compliquer le NLP. Rakuten étant une entreprise mondiale, on peut s'attendre à ce que bien plus que 3 langues soient représentées dans le jeu de données.

# %%
print('\n#\n'.join(X.designation.iloc[:100]))
# Out:
# Olivia: Personalisiertes Notizbuch / 150 Seiten / Punktraster / Ca Din A5 / Rosen-Design
# #
# Journal Des Arts (Le) N° 133 Du 28/09/2001 - L'art Et Son Marche Salon D'art Asiatique A Paris - Jacques Barrere - Francois Perrier - La Reforme Des Ventes Aux Encheres Publiques - Le Sna Fete Ses Cent Ans.
# #
# Grand Stylet Ergonomique Bleu Gamepad Nintendo Wii U - Speedlink Pilot Style
# #
# Peluche Donald - Europe - Disneyland 2000 (Marionnette À Doigt)
# #
# La Guerre Des Tuques
# #
# Afrique Contemporaine N° 212 Hiver 2004 - Dossier Japon / Afrique
# #
# Christof E: Bildungsprozessen Auf Der Spur
# #
# Conquérant Sept Cahier Couverture Polypro 240 X 320 Mm 96 Pages 90g Seyès Incolore
# #
# Puzzle Scooby-Doo Avec Poster 2x35 Pieces
# #
# Tente Pliante V3s5-Pro Pvc Blanc - 3 X 4m50 - Longueur : 4m50 Largeur : 3 M Blanc H
# #
# Eames Inspired Sxw Chair - Pink - Black
# #
# Fauteuil Chesterfield Brenton 100% Cuir De Buffle - Vert Empire
# #
# Peaceable Kingdom Wheres Bear? The Hide And Find Stacking Block Game For 2 Year Olds
# Pince agrafeuse 591 N°10. Capot en ABS. Dispositif anti-blocage. Mécanisme et corps métal. Agrafage : 15 feuilles.  Capacité : 200 agrafes n°10. Profondeur de gorge : 46 mm. Livrée avec 1 boîte d&#39;agrafes n°10. En boite individuelle.
# #
# Original Barbie Doll. Contains glitter lotion..
# #
# véhicule vintage de la saga star wars le A-AST5
# #
# Mini Wifi 720P Caméra Drone RC Quadcopter 24 GHz 4CH 6-Axis Gyro 3D UFO FPV RC Description: Marque: DHD D4 Point NO.:D4 Fréquence: 24 GHz canal: 4 canaux Axe: 6 axes Couleur: Vert bleu Copter batterie: 3.7V 220mAh temps de vol: A propos 6mins temps de charge: à propos de 50mins contrôle à distance: environ 50 m taille du produit: 105 * 105 * 3cm Caractéristiques: 4 canaux mini quadcopter. le mode de détection de gravité rend plus intéressant de contrôler le drone. Avec la caméra 720P il permet de prendre des photos et enregistrer des vidéos. Wifi FPV en temps réel apporte le monde devant vous. Avec la lumière LED pour la nuit flight.With 3D flips « n » roll peut rendre votre vol plus drôle. vous permettent de voir la vue HD en direct de la caméra FPV et tenir au courant de ce qui se passe dans l&#39;air. la technologie 2.4G adoptée pour l&#39;anti-ingérence. encore plus d&#39;un quadcopter vole en même temps ils ne vont pas interférer les uns avec les autres. 6-Axis vol quad-giravion gyroscope une forte stabilité peut facilement mettre en ¿uvre divers mouvements de vol plus forte résistance au vent plus facile à contrôler. Avec la lumière LED deviennent plus en sécurité dans le ciel nocturne. mini portable cellule de pliage peuvent être montés dans le contrôle à distance de véhicules aériens équipés de plein air sac de vol Voyage facile sans pression Fonctions: haut / bas tourner à gauche / droite avant / arrière gauche / droite sidewayfly flips 3D « n » roll avec LED paquet contient: 1 x Quadcopter (720p camera sans fil) 1 x batterie 1 x télécommande 1 x étui de protection extérieure 1 x support de téléphone 1 x Quadcoper chargeur USB 4 x 4 garde lame x 1 x Manuel peut facilement mettre en ¿uvre divers mouvements de vol plus forte résistance au vent plus facile à contrôler. Avec la lumière LED deviennent plus en sécurité dans le ciel nocturne. mini portable cellule de pliage peuvent être montés dans le contrôle à distance de véhicules aériens équipés de plein air sac de vol Voyage facile sans pression Fonctions: haut / bas tourner à gauche / droite avant / arrière gauche / droite sidewayfly flips 3D « n » roll avec LED paquet contient: 1 x Quadcopter (720p camera sans fil) 1 x batterie 1 x télécommande 1 x étui de protection extérieure 1 x support de téléphone 1 x Quadcoper chargeur USB 4 x 4 garde lame x 1 x Manuel peut facilement mettre en ¿uvre divers mouvements de vol plus forte résistance au vent plus facile à contrôler. Avec la lumière LED deviennent plus en sécurité dans le ciel nocturne. mini portable cellule de pliage peuvent être montés dans le contrôle à distance de véhicules aériens équipés de plein air sac de vol Voyage facile sans pression Fonctions: haut / bas tourner à gauche / droite avant / arrière gauche / droite sidewayfly flips 3D « n » roll avec LED paquet contient: 1 x Quadcopter (720p camera sans fil) 1 x batterie 1 x télécommande 1 x étui de protection extérieure 1 x support de téléphone 1 x Quadcoper chargeur USB 4 x 4 garde lame x 1 x Manuel
# #
# 4pcs alliage métallique 1.9in jante de roue pour 1/10 Traxxas TRX4 HSP SCX10 D90 RC Car Description: Ces haute qualité moyeux de roue 19 pouces sont en alliage métallique durable et solide. Ils conviennent pour les pneus de 1/10 Traxxas HSP Redcat Tamiya axiale SCX10 D90 Hpi RC 4 roues motrices voiture. Avec sa qualité formidable et la performance il peut répondre aux besoins des utilisateurs. Alors venez prendre la maison excellent choix vous permettra de profiter plus de plaisir. 19 pouces jante de la roue de blocage. En métal et 100% tout neuf et durable. Diamètre extérieur: 54 mm Epaisseur: 25 mm de jante de roue Hex: 15mm Taille du paquet: 115 x 115 x 28 cm Couleur: Noir Poids: 250g Matériel: Métal Package comprend: 4 x moyeu de roue
# #
# FABER-CASTELL Crayon de couleur POLYCHROMOS vert émeraudepour artistes hexagonal résistant à l&#39;essuyage et auxintempéries mine craie à l&#39;huile solideépaisseur de mine: 38 mm longueur: 176 mm(110163)couleur: 163

# %% [markdown]
# Les descriptions aussi sont confuses et parsemées de parasites variés. Leurs tailles sont très variables. L'absence de description pour 35% des données représente aussi une difficulté.

# %%
#TODO? histogram
# Designation lengths (character counts)
X.designation.apply(len).describe()
# Out:
# count    84916.000000
# mean        70.163303
# std         36.793383
# min         11.000000
# 25%         43.000000
# 50%         64.000000
# 75%         90.000000
# max        250.000000
# Name: designation, dtype: float64

# %%
#TODO? histogram
# description lengths (character counts) (except for missing descriptions)
X.description.dropna().apply(len).describe()
# Out:
# count    55116.000000
# mean       808.171692
# std        805.462153
# min          1.000000
# 25%        259.000000
# 50%        626.000000
# 75%       1034.000000
# max      12451.000000
# Name: description, dtype: float64

# %%
#TODO? values and plot: moyenne de la longueur de la description par type de produit

# %% [markdown]
# 70 descriptions font moins de 5 caractères et semblent presque toutes inutiles à la prédiction. Heureusement, elles ne représentent que 0,1% du jeu de données.

# %%
# Taille, Nombre de descriptions de cette taille
v=X.description.dropna().apply(len)[X.description.dropna().apply(len) <= 5].value_counts().sort_index()
v
# Out:
# description
# 1    28
# 2     9
# 3    14
# 4    19
# 5     7
# Name: count, dtype: int64

# %%
# Descriptions de moins de 5 caractères
X.description.dropna()[X.description.dropna().apply(len) <= 5].unique()
# Out:
# array(['50PV.', '1989', '...', 'promo', '-', '0', '1985', '1984', 'nc',
#        '.', 'Batty', '(1', 'p', 'jeu', '1972.', '&gt;', '1980', 'Buste',
#        'Noir', '1969', 'aa', 'Gris', 'B1962', '3323', '1988', '1947',
#        '1986', '1991', '1992', '--', '1996', 'table'], dtype=object)

# %%
# Nombre et pourcentage de ces descriptions
v.sum(),v.sum()/X.description.dropna().shape[0]
# Out:
# (np.int64(70), np.float64(0.001270048624718775))

# %% [markdown]
# À partir de 6 caractères, les descriptions commencent à sembler utiles à la prédiction : par exemple, "Roman", "Chevet", "Proust".

# %%
# Descriptions de 6 caractères
X.description.dropna()[X.description.dropna().apply(len) == 6].unique()
# Out:
# array(['<br />', 'doudou', 'Notice', 'Roman.', 'argent', 'F.215.',
#        'Proust', 'Marron', '18X7cm', 'Chevet'], dtype=object)

# %%
# Descriptions de 7 caractères
X.description.dropna()[X.description.dropna().apply(len) == 7].unique()
# Out:
# array(['Piano -', '34x29cm', '2259.00', 'Mensuel', '...<br>', 'Commode',
#        'RoHS CE', 'Poupon '], dtype=object)

# %% [markdown]
# #### Wordclouds

# %% [markdown]
# ##### Variable designation

# %%
# Complète l'installation de nltk. Utile seulement une fois par PC.
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /home/val/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords

# Initialiser la variable des mots vides
stop_words = set(stopwords.words('french'))
print(stop_words)
# Out:
# {'aurait', 'seras', 'fusse', 'fusses', 'dans', 'votre', 'étant', 'seront', 'aurai', 'la', 'étaient', 'ai', 'on', 'eus', 't', 'été', 'auras', 'mes', 'eusse', 'ton', 'aura', 'eux', 'serions', 'un', 'eussent', 'étées', 'à', 'leur', 'sa', 'les', 'en', 'avons', 'aient', 'était', 'notre', 'eu', 'eusses', 'étions', 'serez', 'aurons', 'fût', 'lui', 'ces', 'aurions', 'y', 'ayons', 'même', 'eût', 'auront', 'ayantes', 'aux', 'étée', 'serait', 'eue', 'ma', 'd', 'soyons', 'seraient', 'une', 'le', 'ses', 's', 'serai', 'eussions', 'étais', 'nous', 'du', 'soyez', 'tu', 'fussions', 'vous', 'eûmes', 'auriez', 'sommes', 'vos', 'eues', 'avaient', 'ou', 'se', 'furent', 'mais', 'ait', 'avions', 'son', 'aurez', 'me', 'auraient', 'c', 'nos', 'êtes', 'pas', 'soient', 'qui', 'ayants', 'pour', 'tes', 'eussiez', 'est', 'm', 'je', 'sont', 'qu', 'étés', 'avez', 'étiez', 'sur', 'fus', 'fut', 'ayez', 'étante', 'soit', 'aviez', 'j', 'fussiez', 'as', 'sois', 'et', 'l', 'serons', 'sera', 'il', 'toi', 'ils', 'serais', 'avais', 'avec', 'eut', 'fûmes', 'aies', 'ayant', 'ce', 'ont', 'ne', 'mon', 'aurais', 'n', 'elle', 'eurent', 'moi', 'ayante', 'étants', 'des', 'que', 'aie', 'es', 'eûtes', 'étantes', 'seriez', 'suis', 'fûtes', 'ta', 'avait', 'au', 'de', 'par', 'fussent', 'te'}

# %%
from wordcloud import WordCloud
wc = WordCloud(background_color="black", max_words=100, max_font_size=30, stopwords=stop_words, random_state=42)

# %%
text = ' '.join(X.designation)
wc.generate(text)
len(text)
# Out:
# 6042902

# %%
import matplotlib.pyplot as plt

# Générer et afficher le nuage de mots

plt.figure(figsize=(13,5))
plt.imshow(wc)
plt.show()

# %% [markdown]
# ##### Variable description

# %%
#TODO wordcloud

# %%
wc = WordCloud(background_color="black", max_words=100, max_font_size=30, stopwords=stop_words, random_state=42)

# %%
text = ' '.join(X.description.dropna())
wc.generate(text)
len(text)
# Out:
# 44598306

# %%
plt.figure(figsize=(13,5))
plt.imshow(wc)
plt.show()

# %% [markdown]
# #### TODO : Mots les plus fréquents

# %%
# # TODO : plot distribution des mots les plus fréquents

# from collections import Counter
# import seaborn as sns
# chaine = ' '.join(i.lower() for i in df_neg.Text)
# dico = Counter(chaine.split())
# mots = [m[0] for m in dico.most_common(15)]
# freq = [m[1] for m in dico.most_common(15)]

# plt.figure(figsize= (10,6))
# sns.barplot(x=mots, y=freq)
# plt.title('15 mots les plus fréquemment employés par les internautes laissant des mauvais commentaires')

# %% [markdown]
# ## Variable cible

# %%
y = pd.read_csv('../Dataset/Y_train.csv',index_col=0)
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 84916 entries, 0 to 84915
# Data columns (total 1 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   prdtypecode  84916 non-null  int64
# dtypes: int64(1)
# memory usage: 1.3 MB

# %%
if not y.index.is_unique:
    print("Warning: Duplicate indices found!")

# %%
y.head(15)
# Out:
#     prdtypecode
# 0            10
# 1          2280
# 2            50
# 3          1280
# 4          2705
# 5          2280
# 6            10
# 7          2522
# 8          1280
# 9          2582
# 10         1560
# 11         1560
# 12         1281
# 13         1920
# 14         1560

# %%
y.prdtypecode.nunique()
# Out:
# 27

# %%
y.prdtypecode.unique()
# Out:
# array([  10, 2280,   50, 1280, 2705, 2522, 2582, 1560, 1281, 1920, 2403,
#        1140, 2583, 1180, 1300, 2462, 1160, 2060,   40,   60, 1320, 1302,
#        2220, 2905, 2585, 1940, 1301])

# %% [markdown]
# Le graphique de Jessy montre en fait tous les codes produits, pas une liste abrégée ! Le préciser dans le rendu.

# %%
y.describe()
# Out:
#         prdtypecode
# count  84916.000000
# mean    1773.219900
# std      788.179885
# min       10.000000
# 25%     1281.000000
# 50%     1920.000000
# 75%     2522.000000
# max     2905.000000

# %%
y.value_counts()
# Out:
# prdtypecode
# 2583           10209
# 1560            5073
# 1300            5045
# 2060            4993
# 2522            4989
# 1280            4870
# 2403            4774
# 2280            4760
# 1920            4303
# 1160            3953
# 1320            3241
# 10              3116
# 2705            2761
# 1140            2671
# 2582            2589
# 40              2508
# 2585            2496
# 1302            2491
# 1281            2070
# 50              1681
# 2462            1421
# 2905             872
# 60               832
# 2220             824
# 1301             807
# 1940             803
# 1180             764
# Name: count, dtype: int64

# %%
v=y.value_counts(normalize=True).tolist()
v
# Out:
# [0.12022469263742994,
#  0.05974139149276932,
#  0.05941165386970653,
#  0.058799283998304204,
#  0.05875217862358095,
#  0.057350793725564085,
#  0.05622026473220595,
#  0.05605539592067455,
#  0.05067360685854256,
#  0.04655188657025767,
#  0.03816712986951811,
#  0.03669508690941636,
#  0.0325144849027274,
#  0.031454613971454146,
#  0.030488953789627397,
#  0.029535069951481464,
#  0.029393753827311696,
#  0.029334872108907627,
#  0.02437703141928494,
#  0.0197960337274483,
#  0.016734184370436667,
#  0.010268971689669792,
#  0.009797917942437232,
#  0.00970370719299072,
#  0.009503509350416883,
#  0.009456403975693627,
#  0.008997126572141882]

# %%
import numpy as np
ratios = [v[k]/v[-1] for k in range(len(v))]
max(ratios),np.median(ratios),np.std(ratios) #,np.mean(ratios)-np.std(ratios),np.mean(ratios)+np.std(ratios)
# Out:
# (13.362565445026178,
#  np.float64(3.4960732984293195),
#  np.float64(2.7014821668350457))

# %% [markdown]
# Comme l'indique le graphique de Jessy, les catégories sont déséquilibrées : la plupart des catégories sont 3 à 13 fois plus représentées que la plus rare. Les rééquilibrer pourrait améliorer la performance.
